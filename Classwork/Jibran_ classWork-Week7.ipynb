# %% [markdown]
# ### Exercise 1 - Using the math library
#
#
# Import the math library in your program and do the following
#
# 1. Request the user to enter a number between 1 and 10
# 2. Compute the log (math.log) of the number
# 3. Compute the factorial (math.factorial) of the number
# 4. Compute the square root (math.sqrt) of the number
# 5. Compute the sine (math.sin) of the number

# %%
import math

number = int(input("Enter a number between 1 and 10: "))

if 1 <= number <= 10:
    log_value = math.log(number)
    factorial_value = math.factorial(number)
    sqrt_value = math.sqrt(number)
    sine_value = math.sin(number)

    print(f"Logarithm (base e) of {number}: {log_value}")
    print(f"Factorial of {number}: {factorial_value}")
    print(f"Square root of {number}: {sqrt_value}")
    print(f"Sine of {number}: {sine_value}")
else:
    print("Please enter a number between 1 and 10.")
# Out:
# Enter a number between 1 and 10: 2
# Logarithm (base e) of 2: 0.6931471805599453
# Factorial of 2: 2
# Square root of 2: 1.4142135623730951
# Sine of 2: 0.9092974268256817

# %% [markdown]
# Exercise 2 - Now use from math then import all of the function you need to use and redo Exercise 1 by using the functions directly

# %%
from math import log, factorial, sqrt, sin

number = int(input("Enter a number between 1 and 10: "))

if 1 <= number <= 10:
    log_value = log(number)
    factorial_value = factorial(number)
    sqrt_value = sqrt(number)
    sine_value = sin(number)

    print(f"Logarithm (base e) of {number}: {log_value}")
    print(f"Factorial of {number}: {factorial_value}")
    print(f"Square root of {number}: {sqrt_value}")
    print(f"Sine of {number}: {sine_value}")
else:
    print("Please enter a number between 1 and 10.")
# Out:
# Enter a number between 1 and 10: 2
# Logarithm (base e) of 2: 0.6931471805599453
# Factorial of 2: 2
# Square root of 2: 1.4142135623730951
# Sine of 2: 0.9092974268256817
