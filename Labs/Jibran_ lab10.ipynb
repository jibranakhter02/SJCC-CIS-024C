# %% [markdown]
# # CIS024C -  Fall 2024
#
# ## Lab 10
#
# *Lab 10 tests the below content*
#
# Python Classes
#
# - Basic Ideas
# - Operator overloading

# %% [markdown]
# #### Exercise 1
#
# Create a Python class **Calculator** with four member functions - add, subtract, multiply and divide
#
# __init__ method accepts two numbers
#
# __str__ method displays the numbers when the object is displayed using the print method
#
# Example: print(calcObject)
# Number 1: 10, Number 2: 20
#
#
# **Output**
#
# ```
#
# Enter the first number: 10
# Enter the second number: 20
#
# Number 1: 10, Number 2: 20
#
# Sum: 30
# Difference: -10
# Product: 300
# Quotient: 0.5
# ```

# %%
### YOUR CODE GOES BELOW
class Calculator:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    def add(self):
        return self.num1 + self.num2

    def subtract(self):
        return self.num1 - self.num2

    def multiply(self):
        return self.num1 * self.num2

    def divide(self):
        if self.num2 != 0:
            return self.num1 / self.num2
        else:
            return "Error: Division by zero"

    def __str__(self):
        return f"Number 1: {self.num1}, Number 2: {self.num2}"
### END CODE

# %%
### YOUR CODE GOES BELOW
if __name__ == "__main__":
    num1 = float(input("Enter the first number: "))
    num2 = float(input("Enter the second number: "))

    calc = Calculator(num1, num2)

    print(calc)

    print(f"Sum: {calc.add()}")
    print(f"Difference: {calc.subtract()}")
    print(f"Product: {calc.multiply()}")
    print(f"Quotient: {calc.divide()}")
### END CODE
# Out:
# Enter the first number: 1
# Enter the second number: 2
# Number 1: 1.0, Number 2: 2.0
# Sum: 3.0
# Difference: -1.0
# Product: 2.0
# Quotient: 0.5

# %% [markdown]
# #### Exercise 2
# Write a Python class called Employee with the following properties. Initialize the attributes during class creation. Instantiate the class and invoke its methods
#
# **Attributes**
# Name
# Age
# Salary
#
# **Methods**
# getName
# getAge
# getSalary.

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary

    def getName(self):
        return self.name

    def getAge(self):
        return self.age

    def getSalary(self):
        return self.salary
### END CODE

# %%
### YOUR CODE GOES BELOW
if __name__ == "__main__":
    name = input("Enter the employee's name: ")
    age = int(input("Enter the employee's age: "))
    salary = float(input("Enter the employee's salary: "))

    emp = Employee(name, age, salary)

    print(f"Employee Name: {emp.getName()}")
    print(f"Employee Age: {emp.getAge()}")
    print(f"Employee Salary: {emp.getSalary()}")
### END CODE
# Out:
# Enter the employee's name: John
# Enter the employee's age: 12
# Enter the employee's salary: 100
# Employee Name: John
# Employee Age: 12
# Employee Salary: 100.0

# %% [markdown]
# #### Exercise 3 (20 points)
#
# Add support to the previous class to allow for setting attributes of the members variables in the class using member functions. Make sure the actual member variables are private and cannot be accessed outside the class.
#
# Instantiate the class and invoke its methods
#
# You will add the below member functions in the class, and allow for updating of class attributes using these member functions
#
# setName
# setAge

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, name, age, salary):
        self.__name = name
        self.__age = age
        self.__salary = salary

    def getName(self):
        return self.__name

    def getAge(self):
        return self.__age

    def getSalary(self):
        return self.__salary

    def setName(self, name):
        self.__name = name

    def setAge(self, age):
        self.__age = age

    def setSalary(self, salary):
        self.__salary = salary


if __name__ == "__main__":
    name = input("Enter the employee's name: ")
    age = int(input("Enter the employee's age: "))
    salary = float(input("Enter the employee's salary: "))

    emp = Employee(name, age, salary)

    print(f"\nInitial Employee Info:")
    print(f"Employee Name: {emp.getName()}")
    print(f"Employee Age: {emp.getAge()}")
    print(f"Employee Salary: {emp.getSalary()}")

    new_name = input("\nEnter the new name: ")
    new_age = int(input("Enter the new age: "))

    emp.setName(new_name)
    emp.setAge(new_age)

    print(f"\nUpdated Employee Info:")
    print(f"Employee Name: {emp.getName()}")
    print(f"Employee Age: {emp.getAge()}")
    print(f"Employee Salary: {emp.getSalary()}")
### END CODE
# Out:
# Enter the employee's name: John
# Enter the employee's age: 12
# Enter the employee's salary: 100
#
# Initial Employee Info:
# Employee Name: John
# Employee Age: 12
# Employee Salary: 100.0
#
# Enter the new name: John Deecan
# Enter the new age: 13
#
# Updated Employee Info:
# Employee Name: John Deecan
# Employee Age: 13
# Employee Salary: 100.0

# %% [markdown]
# #### Exercise 4
#
# For the Employee class, write a method that will print class details with the print method. Instantiate the class and invoke its methods.
#
# **Example**
#
# When print(employeeObject) is invoked the output should be
#
# ```
# Name: Bob Wasserman
# Age: 47
# Salary: 110000
# ```

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, name, age, salary):
        self.__name = name
        self.__age = age
        self.__salary = salary

    def getName(self):
        return self.__name

    def getAge(self):
        return self.__age

    def getSalary(self):
        return self.__salary

    def setName(self, name):
        self.__name = name

    def setAge(self, age):
        self.__age = age

    def setSalary(self, salary):
        self.__salary = salary

    def __str__(self):
        return f"Name: {self.__name}\nAge: {self.__age}\nSalary: {self.__salary}"

if __name__ == "__main__":
    name = input("Enter the employee's name: ")
    age = int(input("Enter the employee's age: "))
    salary = float(input("Enter the employee's salary: "))

    emp = Employee(name, age, salary)

    print(emp)
### END CODE
# Out:
# Enter the employee's name: John
# Enter the employee's age: 12
# Enter the employee's salary: 100
# Name: John
# Age: 12
# Salary: 100.0

# %% [markdown]
# #### Exercise 5
#
# Create a Python class called Teacher derived from the Employee class. Add the below properties and methods to the Teacher class.
#
# *Attributes*
#
# Course Name
#
# *Methods*
#
# getCourseName
#
# Initialize the course name in the constructor. Invoke the class method to display the course name

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, name, age, salary):
        self.__name = name
        self.__age = age
        self.__salary = salary

    def getName(self):
        return self.__name

    def getAge(self):
        return self.__age

    def getSalary(self):
        return self.__salary

    def setName(self, name):
        self.__name = name

    def setAge(self, age):
        self.__age = age

    def setSalary(self, salary):
        self.__salary = salary

    def __str__(self):
        return f"Name: {self.__name}\nAge: {self.__age}\nSalary: {self.__salary}"

class Teacher(Employee):
    def __init__(self, name, age, salary, course_name):
        super().__init__(name, age, salary)
        self.__course_name = course_name

    def getCourseName(self):
        return self.__course_name

    def __str__(self):
        return super().__str__() + f"\nCourse Name: {self.__course_name}"

if __name__ == "__main__":
    name = input("Enter the teacher's name: ")
    age = int(input("Enter the teacher's age: "))
    salary = float(input("Enter the teacher's salary: "))
    course_name = input("Enter the course name: ")

    teacher = Teacher(name, age, salary, course_name)

    print(teacher)
### END CODE
# Out:
# Enter the teacher's name: Mary Cabanayan
# Enter the teacher's age: 40
# Enter the teacher's salary: 50000
# Enter the course name: GUIDE096
# Name: Mary Cabanayan
# Age: 40
# Salary: 50000.0
# Course Name: GUIDE096
