# %% [markdown]
# # CIS024C -  Fall 2024
#
# ## Homework 10

# %% [markdown]
# #### Exercise 1 - Class creation **
#
# Create a Python class named **Employee** with the following attributes and methods
#
# Data members
# ```
# 1. employeeName  - type string
# 2. employeeAge  - type int
# 3. employeeSalary - type float
# ```
#
# Methods:
# ```
# 1. getEmployee - returns employee name
# 2. getEmployeeAge - gets the employee age
# 3. getEmployeeSalary - returns the employee salary
# 4. __init__ - initialize method accepts the name, age and salary of the employee
# ```
#
# Create an object of type Employee and initialize with arbitrary values. Invoke the get methods and display the result.

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, employeeName, employeeAge, employeeSalary):
        self.employeeName = employeeName
        self.employeeAge = employeeAge
        self.employeeSalary = employeeSalary

    def getEmployee(self):
        return self.employeeName

    def getEmployeeAge(self):
        return self.employeeAge

    def getEmployeeSalary(self):
        return self.employeeSalary

employee = Employee("John Doe", 30, 75000.00)

print("Employee Name:", employee.getEmployee())
print("Employee Age:", employee.getEmployeeAge())
print("Employee Salary:", employee.getEmployeeSalary())
### END CODE
# Out:
# Employee Name: John Doe
# Employee Age: 30
# Employee Salary: 75000.0

# %% [markdown]
# #### Exercise 2 - Private members
#
# In the above **Employee** class make the employeeName, employeeAge and employeeSalary private so that their access is restricted to only within the class.
#
# Note that private variables are member variables of the class that are preceeded with two underscores.
#
# Here is more information on private variables - https://www.geeksforgeeks.org/private-variables-python/

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, employeeName, employeeAge, employeeSalary):
        self.__employeeName = employeeName   # private attribute
        self.__employeeAge = employeeAge     # private attribute
        self.__employeeSalary = employeeSalary  # private attribute

    def getEmployee(self):
        return self.__employeeName

    def getEmployeeAge(self):
        return self.__employeeAge

    def getEmployeeSalary(self):
        return self.__employeeSalary

employee = Employee("John Doe", 30, 75000.00)

print("Employee Name:", employee.getEmployee())
print("Employee Age:", employee.getEmployeeAge())
print("Employee Salary:", employee.getEmployeeSalary())
### END CODE
# Out:
# Employee Name: John Doe
# Employee Age: 30
# Employee Salary: 75000.0

# %% [markdown]
# #### Exercise 3 - Adding setters and working with a list of Employees
#
# In the **Employee** class add the following methods
#
# ```
# 1. setEmployeeAge - accepts age and sets it in the object
# 2. setEmployeeName - accepts employee name and sets it in the object
# 3. setEmployeeSalary - accepts employee salary and sets it i nthe object
# ```
#
# ##### Create a list of employees called employeeList. Initialize the list with three objects of type Employee. Initialize each employee in the list with the values "None" for employeeName, 0 for employeeAge and 0 for employeeSalary.
#
# Example:
#
# Employee 1:
# Name: "None", Age: 0, Salary: 0
#
# Employee 2:
# Name: "None", Age: 0, Salary: 0
#
# Employee 3:
# Name: "None", Age: 0, Salary: 0
#
# EmployeeList should have 3 employee objects at the end of this step.
#
# ##### Loop  through each employee in the employeeList. Each time, request the user to enter the name, age and salary of a different employee. Use the set methods to set the name, age and salary for each employee in the employeeList.
#
# Loop through employees list
#     Set employee name
#     Set employee age
#     Set employee salary
#
# ##### Loop through each employee in the employeeList. Display the name, age and salary of each employee.
#
# Loop through employees list
#     Use getter to display employee name
#     Use getter to display  employee age
#     Use getter to display  employee salary

# %%
### YOUR CODE GOES BELOW
class Employee:
    def __init__(self, employeeName="None", employeeAge=0, employeeSalary=0):
        self.__employeeName = employeeName   # private attribute
        self.__employeeAge = employeeAge     # private attribute
        self.__employeeSalary = employeeSalary  # private attribute

    def getEmployee(self):
        return self.__employeeName

    def getEmployeeAge(self):
        return self.__employeeAge

    def getEmployeeSalary(self):
        return self.__employeeSalary

    def setEmployeeName(self, name):
        self.__employeeName = name

    def setEmployeeAge(self, age):
        self.__employeeAge = age

    def setEmployeeSalary(self, salary):
        self.__employeeSalary = salary


employeeList = [Employee() for _ in range(3)]

employee_data = [
    ("Alice", 25, 50000.00),
    ("Bob", 30, 60000.00),
    ("Charlie", 28, 55000.00)
]

for i, emp in enumerate(employeeList):
    name = input(f"Enter the name of Employee {i + 1}: ")
    age = int(input(f"Enter the age of Employee {i + 1}: "))
    salary = float(input(f"Enter the salary of Employee {i + 1}: "))

    name, age, salary = employee_data[i]
    emp.setEmployeeName(name)
    emp.setEmployeeAge(age)
    emp.setEmployeeSalary(salary)

print("\nEmployee Details:")
for i, emp in enumerate(employeeList):
    print(f"Employee {i + 1}:")
    print(f"Name: {emp.getEmployee()}")
    print(f"Age: {emp.getEmployeeAge()}")
    print(f"Salary: {emp.getEmployeeSalary()}")
    print()
### END CODE
# Out:
# Enter the name of Employee 1: None
# Enter the age of Employee 1: 0
# Enter the salary of Employee 1: 0
# Enter the name of Employee 2: None
# Enter the age of Employee 2: 0
# Enter the salary of Employee 2: 0
# Enter the name of Employee 3: None
# Enter the age of Employee 3: 0
# Enter the salary of Employee 3: 0
#
# Employee Details:
# Employee 1:
# Name: Alice
# Age: 25
# Salary: 50000.0
#
# Employee 2:
# Name: Bob
# Age: 30
# Salary: 60000.0
#
# Employee 3:
# Name: Charlie
# Age: 28
# Salary: 55000.0

# %% [markdown]
# #### Exercise 4 -  Creating a Python calculator class
#
# Create a Python class called Calculator.
#
# The class has the following data members
#
# ```
# 1. number1 - type float
# 2. number2 - type float
# ```
#
# The class must have the below methods
#
# ```
# 1. add - adds two numbers and returns the result
# 2. subtract - subtracts the first number from the second number and returns the result
# 3. multiply - multiply two numbers and returns the result
# 4. divide - divide the first number by the second number and returns the result
# 5. __init__ - accepts two numbers and uses those numbers to initialize number1 and number2 respectively
# ```
#
# Create an object of the Calculator class. Initialize it with any two arbitrary numbers. Invoke the methods add, subtract, multiple and divide and display the result

# %%
### YOUR CODE GOES
class Calculator:
    def __init__(self, number1, number2):
        self.number1 = number1
        self.number2 = number2

    def add(self):
        return self.number1 + self.number2

    def subtract(self):
        return self.number1 - self.number2

    def multiply(self):
        return self.number1 * self.number2

    def divide(self):
        if self.number2 == 0:
            return "Cannot divide by zero"
        return self.number1 / self.number2

number1 = float(input("Enter the first number: "))
number2 = float(input("Enter the second number: "))

calc = Calculator(number1, number2)

print(f"Addition: {calc.add()}")
print(f"Subtraction: {calc.subtract()}")
print(f"Multiplication: {calc.multiply()}")
print(f"Division: {calc.divide()}")
### END CODE
# Out:
# Enter the first number: 1
# Enter the second number: 2
# Addition: 3.0
# Subtraction: -1.0
# Multiplication: 2.0
# Division: 0.5

# %% [markdown]
# #### Exercise 5

# %% [markdown]
# In this problem, you will make a Person class and create an address book for storing the contacts of your friends and family. It should allow you to search the address book for a friend, and return their contact information.
#
# Begin by defining an   init   method. Don’t forget about Python's built-­‐in dictionary data type.
#
# Next, write a method add_contact that allows you to add a new person to the address book.
#
# Finally, write a method lookup_contact that looks up a contact by last name. The method should accept the last name as an argument, and print each contact that matches the last name on a new line. As an additional challenge, extend this method to allow users to optionally specify a first name to narrow down the results when multiple contacts have the same last name. To learn more about optional arguments in Python, search for terms such as “optional arguments in Python” and “default arguments in Python”.
#
# For example, suppose the contact book contains entries for both Ali Kamil, and his wife Sama Kamil. The following is an example output:

# %%
### YOUR CODE GOES
class Person:
    def __init__(self):
        self.address_book = {}

    def add_contact(self, first_name, last_name, phone_number):
        full_name = (first_name, last_name)
        self.address_book[full_name] = phone_number

    def lookup_contact(self, last_name, first_name=None):
        found_contacts = []

        for (fname, lname), phone in self.address_book.items():
            if lname == last_name:
                if first_name is None or fname == first_name:
                    found_contacts.append((fname, lname, phone))

        if found_contacts:
            for contact in found_contacts:
                print(f"Contact found: {contact[0]} {contact[1]}, Phone: {contact[2]}")
        else:
            print(f"No contact found with last name '{last_name}'")

address_book = Person()

first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
phone_number = input("Enter your phone number: ")

address_book.add_contact(first_name, last_name, phone_number)

print(f"Your contact ({first_name} {last_name}) has been added with phone number: {phone_number}")

while True:
    action = input("\nWould you like to search for a contact by last name? (y/n): ").lower()

    if action == "n":
        print("Goodbye!")
        break
    elif action == "y":
        search_last_name = input("Enter the last name to search for: ")
        address_book.lookup_contact(search_last_name)
    else:
        print("Invalid input. Please enter 'y' for yes or 'n' for no.")
### END CODE
# Out:
# Enter your first name: Jibran
# Enter your last name: Akhter
# Enter your phone number: 555777666
# Your contact (Jibran Akhter) has been added with phone number: 555777666
#
# Would you like to search for a contact by last name? (y/n): y
# Enter the last name to search for: Akhter
# Contact found: Jibran Akhter, Phone: 555777666
#
# Would you like to search for a contact by last name? (y/n): y
# Enter the last name to search for: Jobs
# No contact found with last name 'Jobs'
#
# Would you like to search for a contact by last name? (y/n): n
# Goodbye!
